# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5,6,7]

y = [1,4,9,16,25,36,49]

plt.title("Our first graph")
plt.xlabel("This is x")
plt.ylabel("this is y")

plt.plot(x,y)

# %%
x = [1,2,3,4,5,6,7]

y = [1,4,9,16,25,36,49]

plt.title("Our first graph", {'fontsize':25, 'color':'red'})
plt.xlabel("This is x", {'fontsize':25, 'color':'black'})
plt.ylabel("this is y")

plt.plot(x,y,color='green')

# %%
x = [1,2,3,4,5,6,7]

y = [1,4,9,16,25,36,49]

plt.title("Our first graph", {'fontsize':25, 'color':'#581845', 'fontname':'DejaVu Sans'})
plt.xlabel("This is x", {'fontsize':25, 'color':'#FF5733'})
plt.ylabel("this is y")

plt.plot(x,y,color='black')

a = [1,3,6,8]
b = [1,6,10,11]
plt.plot(a,b, color='red')

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/petrol_prices.csv')

# %%
df
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %% [markdown]
# Exercise:
# Download petrol_prices.csv and convert it into pandas dataframe.
# Plot Year data in the x-axis and USA data in the y-axis.
# You can make additional formatting (title, x-label, y-label, etc)

# %%
plt.plot(df['Year'], df['USA'], marker='o',label='USA')
plt.plot(df['Year'], df['Canada'], marker='*',label='Canada')
plt.plot(df['Year'], df['Australia'],label='Australia')

plt.xlabel('Year')
plt.ylabel('Petrol Data')
plt.title('Data over the years', {'fontsize':15, 'color':'red'})
plt.legend()

# %% [markdown]
# # **Titanic Dataset**

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

# %%
titanic_df = pd.read_csv(url)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(f"How much missing value in every column: {titanic_df.isna().sum()}")
# Out:
# How much missing value in every column: PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **Who were the passengers on the titanic?**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style='ticks')
plt.style.use('fivethirtyeight')

# %%
sns.catplot(x='Sex', data=titanic_df, kind='count',
            palette='pastel')
plt.title('Count of Passengers by Gender')
plt.show()
# Out:
# <ipython-input-5-fb7823a685ff>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Sex', data=titanic_df, kind='count',

# %%
sns.catplot(x='Pclass', data=titanic_df, hue='Sex', kind='count')

# %% [markdown]
# ** Create a new column 'Person' in which every person under 16 is child.**

# %%
titanic_df['Person'] = titanic_df.Sex
titanic_df.loc[titanic_df['Age'] < 16, 'Person'] = 'Child'

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
titanic_df.Person.unique()
# Out:
# array(['male', 'female', 'Child'], dtype=object)

# %%
titanic_df.Person.value_counts()
# Out:
# Person
# male      537
# female    271
# Child      83
# Name: count, dtype: int64

# %%
titanic_df.Age.mean()
# Out:
# 29.69911764705882

# %%
sns.catplot(x='Pclass', data=titanic_df, hue='Person', kind='count')

# %%
titanic_df.Age.hist(bins=80)
# Out:
# <Axes: >

# %%
fig = sns.FacetGrid(titanic_df, hue='Sex', aspect=4)
fig.map(sns.kdeplot, 'Age', shade=True)

oldest = titanic_df['Age'].max()

fig.set(xlim=(0, oldest))
fig.add_legend()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# # **What deck were the passengers on and how does that relate to their classs**

# %%
titanic_df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Person
# 0      0  A/5 21171   7.2500   NaN        S    male
# 1      0   PC 17599  71.2833   C85        C  female

# %%
deck = titanic_df['Cabin'].dropna()
deck
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
#           ...
# 871            D35
# 872    B51 B53 B55
# 879            C50
# 887            B42
# 889           C148
# Name: Cabin, Length: 204, dtype: object

# %%
levels = []
for level in deck:
  levels.append(level[0])

cabin_df = pd.DataFrame(levels)
cabin_df.columns = ['Cabin']
cabin_df.sort_values(by='Cabin', inplace=True)
sns.catplot(x='Cabin', data=cabin_df, kind='count', palette='pastel')
# Out:
# <ipython-input-17-3118ef9d39a0>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Cabin', data=cabin_df, kind='count', palette='pastel')

# %%
cabin_df = cabin_df[cabin_df.Cabin != 'T']
sns.catplot(x='Cabin', data=cabin_df, kind='count', palette='summer')
# Out:
# <ipython-input-18-1876ba7f870b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Cabin', data=cabin_df, kind='count', palette='summer')

# %% [markdown]
# # **Where did the passengers came from?**

# %%
sns.catplot(x='Embarked',data=titanic_df, hue='Pclass', kind='count', order=['C','Q', 'S'])

# %%
counts = titanic_df.groupby(['Embarked', 'Pclass']).size().reset_index(name='Count')
counts['Percent'] = counts['Count'] / counts['Count'].sum() * 100

g = sns.catplot(data=counts, x='Embarked', hue='Pclass', y='Percent', kind='bar', order=['C', 'Q', 'S'])

for ax in g.axes.flatten():
    for p in ax.patches:
        ax.annotate(f'{p.get_height():.1f}%',
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='baseline',
                    fontsize=12, color='black',
                    xytext=(0, 5),  # Offset text
                    textcoords='offset points')

plt.ylabel('Percentage (%)')
plt.title('Percentage of Passengers by Port of Embarkation and Class')
plt.show()

# %% [markdown]
# # **Who was alone and who was with family?**

# %%
titanic_df['Alone'] = titanic_df.SibSp + titanic_df.Parch
titanic_df.Alone.value_counts()
# Out:
# Alone
# 0     537
# 1     161
# 2     102
# 3      29
# 5      22
# 4      15
# 6      12
# 10      7
# 7       6
# Name: count, dtype: int64

# %%
titanic_df.loc[titanic_df['Alone'] > 0, 'Alone'] = 'With Family'
titanic_df.loc[titanic_df['Alone'] == 0, 'Alone'] = 'Alone'
# Out:
# <ipython-input-22-a9383593559a>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'With Family' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   titanic_df.loc[titanic_df['Alone'] > 0, 'Alone'] = 'With Family'

# %%
titanic_df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Person        Alone
# 0      0  A/5 21171   7.2500   NaN        S    male  With Family
# 1      0   PC 17599  71.2833   C85        C  female  With Family

# %%
sns.catplot(x='Alone', data=titanic_df, kind='count', palette='Blues', order=['Alone', 'With Family'])
# Out:
# <ipython-input-24-6c379b4042e6>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Alone', data=titanic_df, kind='count', palette='Blues', order=['Alone', 'With Family'])

# %%
titanic_df['Sex_Survived'] = titanic_df['Sex'] + '_' + titanic_df['Survived'].astype(str)

# %%
sns.catplot(x='Pclass', data=titanic_df, hue='Sex_Survived', kind='count')
plt.title('Count of Passengers by Class, Sex, and Survival Status')
plt.show()

# %%
sns.catplot(x=deck.str[0], kind='count', palette='pastel')
# Out:
# <ipython-input-28-725468562d22>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x=deck.str[0], kind='count', palette='pastel')

# %% [markdown]
# # **What factors helped someone survive the sinking?**

# %%
titanic_df['Survivor'] = titanic_df.Survived.map({0:'No', 1:'Yes'})

sns.catplot(x='Survivor', data=titanic_df, kind='count', palette='pastel')
# Out:
# <ipython-input-29-6c25a08ea6ec>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Survivor', data=titanic_df, kind='count', palette='pastel')

# %%
sns.catplot(x='Pclass', y='Survived', data=titanic_df, kind='point')

# %%
sns.catplot(x='Pclass', y='Survived', data=titanic_df, hue='Person', kind='point')

# %%
sns.lmplot(x='Age', y='Survived', data=titanic_df)

# %%
sns.lmplot(x='Age', y='Survived',hue='Pclass', data=titanic_df)

# %%
# Calculate survival rates
survival_rate = titanic_df.groupby(['Age', 'Person'])['Survived'].mean().reset_index()
survival_rate['Survived'] *= 100  # Convert to percentage

# Plotting with lmplot
sns.lmplot(x='Age', y='Survived', hue='Person', data=survival_rate)
plt.title('Survival Rate (%) by Age and Class')
plt.ylabel('Survival Rate (%)')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# *   Did the deck have an effect on the passengers survival rate? Did this answer match up with your intuition?
# *   Did having a family member increase the odds of surviving the crash?
